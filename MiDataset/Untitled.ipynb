# %%
import pandas as pd
df = pd.read_csv("manifiesto.csv")
df.shape
# Out:
# (36, 12)

# %%
df.head()
# Out:
#   id_documento            id_pagina             clase  \
# 0     ACT_0001  ACT_0001_pagina_001  actas_nacimiento
# 1     ACT_0002  ACT_0002_pagina_001  actas_nacimiento
# 2     ACT_0003  ACT_0003_pagina_001  actas_nacimiento
# 3     CUR_0001  CUR_0001_pagina_001              curp
# 4     CUR_0002  CUR_0002_pagina_001              curp
#
#                                          ruta_imagen  \
# 0  02_imagenes_convertidas\actas_nacimiento\ACT_0...
# 1  02_imagenes_convertidas\actas_nacimiento\ACT_0...
# 2  02_imagenes_convertidas\actas_nacimiento\ACT_0...
# 3  02_imagenes_convertidas\curp\CUR_0001_pagina_0...
# 4  02_imagenes_convertidas\curp\CUR_0002_pagina_0...
#
#                                    ruta_pdf_original  ancho_pixeles  \
# 0  01_datos_originales\actas_nacimiento\acta de n...         2481.0
# 1  01_datos_originales\actas_nacimiento\Acta_de_N...         2550.0
# 2  01_datos_originales\actas_nacimiento\FOSD06120...         2550.0
# ...

# %%
df.isnull().sum()
# Out:
# id_documento           0
# id_pagina              0
# clase                  0
# ruta_imagen            0
# ruta_pdf_original     30
# ancho_pixeles         30
# alto_pixeles          30
# puntuacion_calidad     0
# necesita_revision      0
# es_aumentada           0
# fecha_procesado        0
# notas                  6
# dtype: int64
